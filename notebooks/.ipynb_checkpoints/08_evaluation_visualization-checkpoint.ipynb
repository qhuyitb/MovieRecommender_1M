# %% [markdown]
# # Evaluation

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Load ranking results (file expected at project root)
df = pd.read_csv('../ranking_results_with_hybrid.csv')
df.head()
# Out:
#   model   K  Precision@K  Recall@K       ARR    NDCG@K     MAP@K  n_users
# 0   SVD   5     0.214000  0.025386  4.341476  0.218436  0.148417      300
# 1   SVD  10     0.196333  0.044524  4.325269  0.206718  0.117311      300
# 2   SVD  20     0.172667  0.072203  4.301426  0.192885  0.093962      300
# 3   NCF   5     0.180000  0.021338  4.416610  0.187462  0.120000      300
# 4   NCF  10     0.163000  0.037532  4.379582  0.175445  0.093580      300

# %%
# Quick pivot for plotting: one row per (model, K) with metrics
plot_df = df.copy()
plot_df['K'] = plot_df['K'].astype(int)
plot_df = plot_df.sort_values(['model','K'])
plot_df.set_index(['model','K'], inplace=True)
plot_df = plot_df[['Precision@K','Recall@K','ARR','NDCG@K','MAP@K']].reset_index()
plot_df.head()
# Out:
#            model   K  Precision@K  Recall@K       ARR    NDCG@K     MAP@K
# 0  Content-Based   5     0.027322  0.002214  3.272477  0.028183  0.013716
# 1  Content-Based  10     0.025683  0.004070  3.265741  0.026607  0.008868
# 2  Content-Based  20     0.022951  0.006437  3.244258  0.024674  0.005911
# 3  Hybrid-Smooth   5     0.209333  0.022939  4.355878  0.216125  0.151631
# 4  Hybrid-Smooth  10     0.180000  0.038534  4.341668  0.195344  0.113652

# %%
# Display full results table (all rows)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df
# Out:
#             model   K  Precision@K  Recall@K       ARR    NDCG@K     MAP@K  \
# 0             SVD   5     0.214000  0.025386  4.341476  0.218436  0.148417
# 1             SVD  10     0.196333  0.044524  4.325269  0.206718  0.117311
# 2             SVD  20     0.172667  0.072203  4.301426  0.192885  0.093962
# 3             NCF   5     0.180000  0.021338  4.416610  0.187462  0.120000
# 4             NCF  10     0.163000  0.037532  4.379582  0.175445  0.093580
# 5             NCF  20     0.153667  0.062171  4.336329  0.168972  0.075991
# 6   Content-Based   5     0.027322  0.002214  3.272477  0.028183  0.013716
# 7   Content-Based  10     0.025683  0.004070  3.265741  0.026607  0.008868
# 8   Content-Based  20     0.022951  0.006437  3.244258  0.024674  0.005911
# 9   Hybrid-Smooth   5     0.209333  0.022939  4.355878  0.216125  0.151631
# 10  Hybrid-Smooth  10     0.180000  0.038534  4.341668  0.195344  0.113652
# 11  Hybrid-Smooth  20     0.150500  0.061812  4.327555  0.174042  0.082693
#
#     n_users
# 0       300
# 1       300
# 2       300
# 3       300
# 4       300
# 5       300
# 6       183
# 7       183
# 8       183
# 9       300
# 10      300
# 11      300

# %%
# Plot function for metric across models and K
def plot_metric(metric, height=4, palette='tab10'):
    plt.figure(figsize=(10, height))
    sns.barplot(data=plot_df, x='K', y=metric, hue='model', palette=palette)
    plt.title(f'{metric} by Model and K')
    plt.ylabel(metric)
    plt.xlabel('K')
    plt.legend(title='Model', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    return plt.gcf()

# %%
# Plot Precision, Recall, NDCG, MAP
for m in ['Precision@K','Recall@K','NDCG@K','MAP@K']:
    fig = plot_metric(m, height=4)
    fname = m.replace('@', 'at')
    fig.savefig(f'../figures/{fname}_by_model.png', dpi=200)
    display(fig)
    plt.close(fig)

# %%
# Plot ARR (separate scale)
fig = plot_metric('ARR', height=3, palette='tab20')
fig.savefig('../figures/ARR_by_model.png', dpi=200)
display(fig)
plt.close(fig)

# %%
# Quick summary: best model per metric/K (by value)
summary = []
metrics = ['Precision@K','Recall@K','ARR','NDCG@K','MAP@K']
for k in sorted(plot_df['K'].unique()):
    dfk = plot_df[plot_df['K']==k]
    for metric in metrics:
        best = dfk.loc[dfk[metric].idxmax()]
        summary.append({'K':k, 'metric':metric, 'best_model':best['model'], 'value':best[metric]})
pd.DataFrame(summary).pivot(index='K', columns='metric', values=['best_model','value']).head()
# Out:
#        best_model                                                value  \
# metric        ARR          MAP@K NDCG@K Precision@K Recall@K       ARR
# K
# 5             NCF  Hybrid-Smooth    SVD         SVD      SVD   4.41661
# 10            NCF            SVD    SVD         SVD      SVD  4.379582
# 20            NCF            SVD    SVD         SVD      SVD  4.336329
#
#
# metric     MAP@K    NDCG@K Precision@K  Recall@K
# K
# 5       0.151631  0.218436       0.214  0.025386
# 10      0.117311  0.206718    0.196333  0.044524
# 20      0.093962  0.192885    0.172667  0.072203
